# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.5 MB 4.4 MB/s eta 0:00:03
#    ------ --------------------------------- 1.8/11.5 MB 5.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.4/11.5 MB 6.1 MB/s eta 0:00:02
#    ------------------ --------------------- 5.2/11.5 MB 6.8 MB/s eta 0:00:01
#    --------------------------- ------------ 7.9/11.5 MB 7.8 MB/s eta 0:00:01
#    --------------------------------- ------ 9.7/11.5 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 7.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv('cities.csv')

# %%
df
# Out:
#      LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"    EW  \
# 0      41        5       59   "N"       80       39        0   "W"
# 1      42       52       48   "N"       97       23       23   "W"
# 2      46       35       59   "N"      120       30       36   "W"
# 3      42       16       12   "N"       71       48        0   "W"
# 4      43       37       48   "N"       89       46       11   "W"
# ..    ...      ...      ...   ...      ...      ...      ...   ...
# 123    39       31       12   "N"      119       48       35   "W"
# 124    50       25       11   "N"      104       39        0   "W"
# 125    40       10       48   "N"      122       14       23   "W"
# 126    40       19       48   "N"       75       55       48   "W"
# 127    41        9       35   "N"       81       14       23   "W"
#
#                  "City"  "State"
# 0          "Youngstown"       OH
# 1             "Yankton"       SD
# 2              "Yakima"       WA
# ...

# %%
df.isnull().sum()
# Out:
# LatD        0
#  "LatM"     0
#  "LatS"     0
#  "NS"       0
#  "LonD"     0
#  "LonM"     0
#  "LonS"     0
# EW          0
#  "City"     0
#  "State"    0
# dtype: int64

# %%
df = df.drop_duplicates()
df
# Out:
#      LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"    EW  \
# 0      41        5       59   "N"       80       39        0   "W"
# 1      42       52       48   "N"       97       23       23   "W"
# 2      46       35       59   "N"      120       30       36   "W"
# 3      42       16       12   "N"       71       48        0   "W"
# 4      43       37       48   "N"       89       46       11   "W"
# ..    ...      ...      ...   ...      ...      ...      ...   ...
# 123    39       31       12   "N"      119       48       35   "W"
# 124    50       25       11   "N"      104       39        0   "W"
# 125    40       10       48   "N"      122       14       23   "W"
# 126    40       19       48   "N"       75       55       48   "W"
# 127    41        9       35   "N"       81       14       23   "W"
#
#                  "City"  "State"
# 0          "Youngstown"       OH
# 1             "Yankton"       SD
# 2              "Yakima"       WA
# ...

# %%
df.columns
# Out:
# Index(['LatD', ' "LatM"', ' "LatS"', ' "NS"', ' "LonD"', ' "LonM"', ' "LonS"',
#        'EW', ' "City"', ' "State"'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace('"', '').str.replace("'", '').str.replace(" ","")

# %%
df
# Out:
#      LatD   LatM   LatS    NS   LonD   LonM   LonS    EW                City  \
# 0      41      5     59   "N"     80     39      0   "W"        "Youngstown"
# 1      42     52     48   "N"     97     23     23   "W"           "Yankton"
# 2      46     35     59   "N"    120     30     36   "W"            "Yakima"
# 3      42     16     12   "N"     71     48      0   "W"         "Worcester"
# 4      43     37     48   "N"     89     46     11   "W"   "Wisconsin Dells"
# ..    ...    ...    ...   ...    ...    ...    ...   ...                 ...
# 123    39     31     12   "N"    119     48     35   "W"              "Reno"
# 124    50     25     11   "N"    104     39      0   "W"            "Regina"
# 125    40     10     48   "N"    122     14     23   "W"         "Red Bluff"
# 126    40     19     48   "N"     75     55     48   "W"           "Reading"
# 127    41      9     35   "N"     81     14     23   "W"           "Ravenna"
#
#      State
# 0       OH
# 1       SD
# ...

# %%
count=df['State'].nunique()
count
# Out:
# np.int64(128)

# %%
sum=df['Population'].sum()
sum
# Out:
# np.int64(34729691)

# %%
import numpy as np

# %%
df['Population'] = np.random.randint(5000, 500000, size=len(df))

# %%
avg=sum/count
avg
# Out:
# np.float64(738929.5957446808)

# %%
max_index = df['Population'].idxmax()
value = df.loc[max_index, 'City']
value
# Out:
# ' "Rocky Mount"'

# %%
min_index = df['Population'].idxmin()
valuemin = df.loc[min_index, 'City']
valuemin
# Out:
# ' "Toronto"'

# %%
df
# Out:
#      LatD  LatM  LatS    NS  LonD  LonM  LonS    EW                City State  \
# 0      41     5    59   "N"    80    39     0   "W"        "Youngstown"    OH
# 1      42    52    48   "N"    97    23    23   "W"           "Yankton"    SD
# 2      46    35    59   "N"   120    30    36   "W"            "Yakima"    WA
# 3      42    16    12   "N"    71    48     0   "W"         "Worcester"    MA
# 4      43    37    48   "N"    89    46    11   "W"   "Wisconsin Dells"    WI
# ..    ...   ...   ...   ...   ...   ...   ...   ...                 ...   ...
# 123    39    31    12   "N"   119    48    35   "W"              "Reno"    NV
# 124    50    25    11   "N"   104    39     0   "W"            "Regina"    SA
# 125    40    10    48   "N"   122    14    23   "W"         "Red Bluff"    CA
# 126    40    19    48   "N"    75    55    48   "W"           "Reading"    PA
# 127    41     9    35   "N"    81    14    23   "W"           "Ravenna"   OH
#
#      Population
# 0         35273
# ...

# %%
df['surface'] = np.random.randint(5000, 500000, size=len(df))

# %%
df
# Out:
#      LatD  LatM  LatS    NS  LonD  LonM  LonS    EW                City State  \
# 0      41     5    59   "N"    80    39     0   "W"        "Youngstown"    OH
# 1      42    52    48   "N"    97    23    23   "W"           "Yankton"    SD
# 2      46    35    59   "N"   120    30    36   "W"            "Yakima"    WA
# 3      42    16    12   "N"    71    48     0   "W"         "Worcester"    MA
# 4      43    37    48   "N"    89    46    11   "W"   "Wisconsin Dells"    WI
# ..    ...   ...   ...   ...   ...   ...   ...   ...                 ...   ...
# 123    39    31    12   "N"   119    48    35   "W"              "Reno"    NV
# 124    50    25    11   "N"   104    39     0   "W"            "Regina"    SA
# 125    40    10    48   "N"   122    14    23   "W"         "Red Bluff"    CA
# 126    40    19    48   "N"    75    55    48   "W"           "Reading"    PA
# 127    41     9    35   "N"    81    14    23   "W"           "Ravenna"   OH
#
#      Population  surface
# ...

# %%
def get_company(s):
  if s.find('Mazda RX4') > -1:
    return 'Mazda'
  elif s.find('Audi') > -1:
    return 'Audi'
  else:
    return 'Unknown'

# %%
df['Population to area ratio'] = df['Population'] / df['surface']

# %%
df
# Out:
#      LatD  LatM  LatS    NS  LonD  LonM  LonS    EW                City State  \
# 0      41     5    59   "N"    80    39     0   "W"        "Youngstown"    OH
# 1      42    52    48   "N"    97    23    23   "W"           "Yankton"    SD
# 2      46    35    59   "N"   120    30    36   "W"            "Yakima"    WA
# 3      42    16    12   "N"    71    48     0   "W"         "Worcester"    MA
# 4      43    37    48   "N"    89    46    11   "W"   "Wisconsin Dells"    WI
# ..    ...   ...   ...   ...   ...   ...   ...   ...                 ...   ...
# 123    39    31    12   "N"   119    48    35   "W"              "Reno"    NV
# 124    50    25    11   "N"   104    39     0   "W"            "Regina"    SA
# 125    40    10    48   "N"   122    14    23   "W"         "Red Bluff"    CA
# 126    40    19    48   "N"    75    55    48   "W"           "Reading"    PA
# 127    41     9    35   "N"    81    14    23   "W"           "Ravenna"   OH
#
# ...
